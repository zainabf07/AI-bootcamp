# %% [markdown]
# <h1 style="color:blue">Pivot basics</h1>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("weather.csv")
df
# Out:
#          date      city  temperature  humidity
# 0  05/01/2024  new york           65        56
# 1  05/02/2024  new york           66        58
# 2  05/03/2024  new york           68        60
# 3  05/01/2024     dubai           75        80
# 4  05/02/2024     dubai           78        83
# 5  05/03/2024     dubai           82        85
# 6  05/01/2024   beijing           80        26
# 7  05/02/2024   beijing           77        30
# 8  05/03/2024   beijing           79        35

# %%
df.pivot(index='city',columns='date')
# Out:
#          temperature                         humidity
# date      05/01/2024 05/02/2024 05/03/2024 05/01/2024 05/02/2024 05/03/2024
# city
# beijing           80         77         79         26         30         35
# dubai             75         78         82         80         83         85
# new york          65         66         68         56         58         60

# %%
df.pivot(index='city',columns='date',values="humidity")
# Out:
# date      05/01/2024  05/02/2024  05/03/2024
# city
# beijing           26          30          35
# dubai             80          83          85
# new york          56          58          60

# %%
df.pivot(index='date',columns='city')
# Out:
#            temperature                humidity
# city           beijing dubai new york  beijing dubai new york
# date
# 05/01/2024          80    75       65       26    80       56
# 05/02/2024          77    78       66       30    83       58
# 05/03/2024          79    82       68       35    85       60

# %%
df.pivot(index='humidity',columns='city')
# Out:
#                 date                         temperature
# city         beijing       dubai    new york     beijing dubai new york
# humidity
# 26        05/01/2024         NaN         NaN        80.0   NaN      NaN
# 30        05/02/2024         NaN         NaN        77.0   NaN      NaN
# 35        05/03/2024         NaN         NaN        79.0   NaN      NaN
# 56               NaN         NaN  05/01/2024         NaN   NaN     65.0
# 58               NaN         NaN  05/02/2024         NaN   NaN     66.0
# 60               NaN         NaN  05/03/2024         NaN   NaN     68.0
# 80               NaN  05/01/2024         NaN         NaN  75.0      NaN
# 83               NaN  05/02/2024         NaN         NaN  78.0      NaN
# 85               NaN  05/03/2024         NaN         NaN  82.0      NaN

# %% [markdown]
# <h1 style="color:blue">Pivot Table</h1>

# %%
df = pd.read_csv("weather2.csv")
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2024  new york           65        56
# 1  5/1/2024  new york           61        54
# 2  5/2/2024  new york           70        60
# 3  5/2/2024  new york           72        62
# 4  5/1/2024     dubai           75        80
# 5  5/1/2024     dubai           78        83
# 6  5/2/2024     dubai           82        85
# 7  5/2/2024     dubai           80        26

# %%
df.pivot_table(index="city",columns="date")
# Out:
#          humidity          temperature
# date     5/1/2024 5/2/2024    5/1/2024 5/2/2024
# city
# dubai        81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %% [markdown]
# <h2 style="color:brown">Margins</h2>

# %%
df.pivot_table(index="city",columns="date", margins=True,aggfunc=np.sum)
# Out:
# C:\Users\binta\AppData\Local\Temp\ipykernel_40752\2241513779.py:1: FutureWarning: The provided callable <function sum at 0x0000020A6E648040> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index="city",columns="date", margins=True,aggfunc=np.sum)
# C:\Users\binta\AppData\Local\Temp\ipykernel_40752\2241513779.py:1: FutureWarning: The provided callable <function sum at 0x0000020A6E648040> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index="city",columns="date", margins=True,aggfunc=np.sum)
# C:\Users\binta\AppData\Local\Temp\ipykernel_40752\2241513779.py:1: FutureWarning: The provided callable <function sum at 0x0000020A6E648040> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.pivot_table(index="city",columns="date", margins=True,aggfunc=np.sum)
#          humidity               temperature
# date     5/1/2024 5/2/2024  All    5/1/2024 5/2/2024  All
# city
# dubai         163      111  274         153      162  315
# new york      110      122  232         126      142  268
# All           273      233  506         279      304  583

# %% [markdown]
# <h2 style="color:brown">Grouper</h2>

# %%
df = pd.read_csv("weather3.csv")
df
# Out:
#         date      city  temperature  humidity
# 0   5/1/2024  new york           65        56
# 1   5/2/2024  new york           61        54
# 2   5/3/2024  new york           70        60
# 3  12/1/2024  new york           30        50
# 4  12/2/2024  new york           28        52
# 5  12/3/2024  new york           25        51

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
# Out:
# C:\Users\binta\AppData\Local\Temp\ipykernel_40752\3780491757.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.pivot_table(index=pd.Grouper(freq='M',key='date'),columns='city')
#              humidity temperature
# city         new york    new york
# date
# 2024-05-31  56.666667   65.333333
# 2024-12-31  51.000000   27.666667
