# %% [markdown]
# #Introduction to TensorFlow

# %% [markdown]
# # 📘 TensorFlow Basics
#
# TensorFlow is a powerful open-source library developed by Google for deep learning and numerical computation. It uses dataflow graphs and automatic differentiation to perform optimized computations.
#
# Let's get started by learning how to use Tensors, which are the fundamental building blocks of TensorFlow.

# %% [markdown]
# ##Installing and Importing TensorFlow

# %%
# !pip install tensorflow -q
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
# Out:
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages)
# TensorFlow version: 2.21.0

# %% [markdown]
# ## 📦 Tensors
#
# Tensors are multi-dimensional arrays (like NumPy arrays). TensorFlow supports scalar (0D), vector (1D), matrix (2D), and higher dimensional tensors.
#
# Let's see how to create and inspect them.

# %% [markdown]
# ##Tensor Creation and Attributes

# %%
# Scalar
scalar = tf.constant(7)
print("Scalar:", scalar)

# Vector
vector = tf.constant([1.0, 2.0, 3.0])
print("Vector:", vector)

# Matrix
matrix = tf.constant([[1, 2], [3, 4]])
print("Matrix:\n", matrix)

# Check shape and dtype
print("Shape:", matrix.shape)
print("Data Type:", matrix.dtype)
# Out:
# Scalar: tf.Tensor(7, shape=(), dtype=int32)
# Vector: tf.Tensor([1. 2. 3.], shape=(3,), dtype=float32)
# Matrix:
#  tf.Tensor(
# [[1 2]
#  [3 4]], shape=(2, 2), dtype=int32)
# Shape: (2, 2)
# Data Type: <dtype: 'int32'>

# %% [markdown]
# ## ➕ Tensor Operations
#
# TensorFlow supports element-wise operations like addition, multiplication, matrix multiplication, etc.

# %% [markdown]
# ##Tensor Arithmetic

# %%
a = tf.constant([[1, 2], [3, 4]])
b = tf.constant([[5, 6], [7, 8]])

# Addition
print("Addition:\n", tf.add(a, b))

# Multiplication (element-wise)
print("Element-wise Multiplication:\n", tf.multiply(a, b))

# Matrix multiplication
print("Matrix Multiplication:\n", tf.matmul(a, b))
# Out:
# Addition:
#  tf.Tensor(
# [[ 6  8]
#  [10 12]], shape=(2, 2), dtype=int32)
# Element-wise Multiplication:
#  tf.Tensor(
# [[ 5 12]
#  [21 32]], shape=(2, 2), dtype=int32)
# Matrix Multiplication:
#  tf.Tensor(
# [[19 22]
#  [43 50]], shape=(2, 2), dtype=int32)

# %% [markdown]
# # 🏗️ Building a Neural Network with TensorFlow (Keras)
#
# We'll use `tf.keras`, a high-level API for building and training models. Let's train a simple neural network to classify digits using the MNIST dataset.

# %% [markdown]
# MNIST stands for
#
# Modified National Institute of Standards and Technology

# %% [markdown]
# ## Load Dataset and Normalize

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize to [0, 1]
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
print(x_train.shape)
# Out:
# (60000, 28, 28)

# %% [markdown]
# ##Define a Model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),  # Input layer
    tf.keras.layers.Dense(128, activation='relu'),  # Hidden layer
    tf.keras.layers.Dense(10, activation='softmax') # Output layer
])
# Out:
# c:\Users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ##Compile and Train

# %%
model.compile(optimizer='adam', #Adaptive Moment Estimation
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=5)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9277 - loss: 0.2561
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9664 - loss: 0.1133
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9761 - loss: 0.0796
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.9819 - loss: 0.0596
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9863 - loss: 0.0450

# %% [markdown]
# ##Evaluate the Model

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print("\nTest Accuracy:", test_acc)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9782 - loss: 0.0713
#
# Test Accuracy: 0.9782000184059143

# %% [markdown]
# #1. Understand the Basic Syntax and Operations (PyTorch)

# %% [markdown]
# # Introduction to PyTorch
# ## 🔥 PyTorch Basics
#
# PyTorch is a popular open-source deep learning library developed by Facebook AI. It provides flexibility and speed through dynamic computation graphs and strong GPU support.
#
# In this section, we'll start by exploring how PyTorch handles tensors and automatic differentiation.

# %% [markdown]
# ##Installing and Importing PyTorch

# %%
# If you're in a notebook or Colab
# !pip install torch -q
import torch
print("PyTorch version:", torch.__version__)
# Out:
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages)
# PyTorch version: 2.13.0+cpu

# %% [markdown]
# ##Creating and Inspecting Tensors
# ## 📦 Tensors in PyTorch
#
# Tensors are multidimensional arrays, just like in NumPy. They're the building blocks of PyTorch and support operations like addition, multiplication, reshaping, etc.

# %% [markdown]
# ##Tensor Creation and Properties

# %%
# Scalar
scalar = torch.tensor(5)
print("Scalar:", scalar)

# Vector
vector = torch.tensor([1.0, 2.0, 3.0])
print("Vector:", vector)

# Matrix
matrix = torch.tensor([[1.0, 2.0], [3.0, 4.0]])
print("Matrix:\n", matrix)

# Shape and data type
print("Shape:", matrix.shape)
print("Data Type:", matrix.dtype)
# Out:
# Scalar: tensor(5)
# Vector: tensor([1., 2., 3.])
# Matrix:
#  tensor([[1., 2.],
#         [3., 4.]])
# Shape: torch.Size([2, 2])
# Data Type: torch.float32

# %% [markdown]
# ## ➕ Tensor Operations
#
# PyTorch supports common element-wise operations as well as matrix multiplication, reshaping, and broadcasting.

# %% [markdown]
# ##Tensor Arithmetic

# %%
a = torch.tensor([[1, 2], [3, 4]], dtype=torch.float32)
b = torch.tensor([[5, 6], [7, 8]], dtype=torch.float32)

# Addition
print("Addition:\n", a + b)

# Element-wise multiplication
print("Element-wise Multiplication:\n", a * b)

# Matrix multiplication
print("Matrix Multiplication:\n", torch.matmul(a, b))
# Out:
# Addition:
#  tensor([[ 6.,  8.],
#         [10., 12.]])
# Element-wise Multiplication:
#  tensor([[ 5., 12.],
#         [21., 32.]])
# Matrix Multiplication:
#  tensor([[19., 22.],
#         [43., 50.]])

# %% [markdown]
# # 🏗️ Building a Neural Network with PyTorch
#
# Now let's build a simple neural network to classify digits from the MNIST dataset using `torch.nn` and `torch.optim`.

# %% [markdown]
# ##Load and Normalize MNIST Dataset

# %%
import torch
print(torch.__version__)
# Out:
# 2.13.0+cpu

# %%
# !pip install torchvision
# Out:
# Requirement already satisfied: torchvision in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (0.28.0)
# Requirement already satisfied: numpy in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (from torchvision) (2.2.5)
# Requirement already satisfied: torch==2.13.0 in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (from torchvision) (2.13.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (from torchvision) (12.2.0)
# Requirement already satisfied: filelock in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (from torch==2.13.0->torchvision) (3.32.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (from torch==2.13.0->torchvision) (4.15.0)
# Requirement already satisfied: setuptools>=77.0.3 in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (from torch==2.13.0->torchvision) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (from torch==2.13.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (from torch==2.13.0->torchvision) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (from torch==2.13.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (from torch==2.13.0->torchvision) (2026.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (from sympy>=1.13.3->torch==2.13.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages (from jinja2->torch==2.13.0->torchvision) (3.0.3)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages)

# %%
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Transform: Normalize to [0, 1]
transform = transforms.ToTensor()

train_data = datasets.MNIST(root='data', train=True, download=True, transform=transform)
test_data = datasets.MNIST(root='data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
test_loader = DataLoader(test_data, batch_size=64, shuffle=False)
# Out:
# 100.0%
# 100.0%
# 100.0%
# 100.0%

# %% [markdown]
# ##Define Neural Network

# %%
import torch.nn as nn
import torch.nn.functional as F

class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        x = x.view(x.shape[0], -1)  # Flatten
        x = F.relu(self.fc1(x))
        return F.log_softmax(self.fc2(x), dim=1)

model = SimpleNN()

# %% [markdown]
# ##Define Loss and Optimizer

# %%
import torch.optim as optim

criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# ##Train the Model

# %%
epochs = 3
for epoch in range(epochs):
    for images, labels in train_loader:
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
    print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
# Out:
# Epoch 1, Loss: 0.3667
# Epoch 2, Loss: 0.0626
# Epoch 3, Loss: 0.2839

# %% [markdown]
# ##Evaluate Accuracy

# %%
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Test Accuracy: {correct / total * 100:.2f}%")
# Out:
# Test Accuracy: 96.85%

# %% [markdown]
# #3. Compare Similarities and Differences with TensorFlow
#
#
# # PyTorch vs TensorFlow: Quick Comparison
#
# | Feature                | PyTorch                               | TensorFlow                           |
# |------------------------|----------------------------------------|--------------------------------------|
# | Execution Mode         | Eager (Dynamic)                        | Eager (Static with option for Graph) |
# | High-Level API         | `torch.nn`, `torch.optim`              | `tf.keras`                           |
# | Dataset Loader         | `DataLoader`                           | `tf.data.Dataset`                    |
# | Training Loop Style    | Mostly manual                          | `model.fit()` or manual              |
# | Model Saving           | `torch.save()`                         | `model.save()` or `SavedModel`       |
# | Visualization Tool     | TensorBoard (via `torch.utils.tensorboard`) | TensorBoard                    |
# | Autograd Support       | Built-in via `autograd`                | `tf.GradientTape()`                  |
#
# Both libraries are capable of building state-of-the-art models. Your choice depends on project needs and comfort with syntax.

# %% [markdown]
# --------------------------------------------------------------------------------

# %% [markdown]
# #Activity
#
# Create two custom models, one with Tensorflow and the other with Pytorch.
# The models should have
#
# ###  Model Architecture (Same for Both Frameworks)
#
# | Layer Type         | Configuration                      |
# |--------------------|-------------------------------------|
# | Input Layer        | Flatten (28×28 → 784)              |
# | Dense Layer 1      | 256 units, ReLU                    |
# | Dropout Layer      | 30% (rate = 0.3)                   |
# | Dense Layer 2      | 128 units, Tanh                    |
# | Output Layer       | 10 units, Softmax (TF) / LogSoftmax (PT) |
#
# ###  Instructions
#
# - Implement this architecture using `tf.keras.Sequential` in TensorFlow.
# - Implement the same architecture using `torch.nn.Module` in PyTorch.
# - Train both models for **5 epochs** using the **Adam optimizer** and an appropriate classification loss.
# - Evaluate accuracy on the MNIST test set.

# %%
# ==========================
# TensorFlow Implementation
# ==========================

import tensorflow as tf

# Load MNIST
(x_train_tf, y_train_tf), (x_test_tf, y_test_tf) = tf.keras.datasets.mnist.load_data()

# Normalize
x_train_tf = x_train_tf.astype("float32") / 255.0
x_test_tf = x_test_tf.astype("float32") / 255.0

# Build Model
tf_model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(128, activation='tanh'),
    tf.keras.layers.Dense(10, activation='softmax')
])

# Compile
tf_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train
tf_model.fit(
    x_train_tf,
    y_train_tf,
    epochs=5,
    batch_size=32,
    validation_split=0.1
)

# Evaluate
tf_loss, tf_acc = tf_model.evaluate(x_test_tf, y_test_tf)
print("TensorFlow Test Accuracy:", tf_acc)
# Out:
# c:\Users\binta\miniconda3\envs\ai-bootcamp\lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9229 - loss: 0.2574 - val_accuracy: 0.9683 - val_loss: 0.1076
# Epoch 2/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9611 - loss: 0.1254 - val_accuracy: 0.9758 - val_loss: 0.0786
# Epoch 3/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9691 - loss: 0.0991 - val_accuracy: 0.9753 - val_loss: 0.0836
# Epoch 4/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9740 - loss: 0.0816 - val_accuracy: 0.9757 - val_loss: 0.0766
# Epoch 5/5
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9763 - loss: 0.0712 - val_accuracy: 0.9788 - val_loss: 0.0749
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9770 - loss: 0.0740
# TensorFlow Test Accuracy: 0.9769999980926514

# %%
# ==========================
# PyTorch Implementation
# ==========================

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader

# Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Dataset
transform = transforms.ToTensor()

train_dataset = datasets.MNIST(
    root="./data",
    train=True,
    download=True,
    transform=transform
)

test_dataset = datasets.MNIST(
    root="./data",
    train=False,
    download=True,
    transform=transform
)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# Model
class CustomNet(nn.Module):
    def __init__(self):
        super(CustomNet, self).__init__()

        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(28*28, 256)
        self.dropout = nn.Dropout(0.3)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 10)

    def forward(self, x):
        x = self.flatten(x)
        x = torch.relu(self.fc1(x))
        x = self.dropout(x)
        x = torch.tanh(self.fc2(x))
        x = torch.log_softmax(self.fc3(x), dim=1)
        return x

model = CustomNet().to(device)

criterion = nn.NLLLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Train
for epoch in range(5):
    model.train()
    running_loss = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    print(f"Epoch {epoch+1}/5, Loss: {running_loss/len(train_loader):.4f}")

# Evaluate
model.eval()

correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f"PyTorch Test Accuracy: {accuracy:.2f}%")
# Out:
# Epoch 1/5, Loss: 0.2603
# Epoch 2/5, Loss: 0.1213
# Epoch 3/5, Loss: 0.0947
# Epoch 4/5, Loss: 0.0794
# Epoch 5/5, Loss: 0.0685
# PyTorch Test Accuracy: 98.05%
